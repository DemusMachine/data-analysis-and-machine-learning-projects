# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\Misha\Downloads\2026.05.26 Job List.xlsx") #change dates
df = df.drop(columns=['ITC STEM Internship Scheme - Job list for CC students (Summer 2026)','Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 15', 'Unnamed: 16'])
df = df.drop([0])
df.to_csv("job list", index=False)
